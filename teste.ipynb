# %%
schema = [{"name":"batchNumber","type":"INTEGER","mode":"NULLABLE"},{"name":"document","type":"INTEGER","mode":"NULLABLE"},{"name":"productCode","type":"STRING","mode":"NULLABLE"},{"name":"creditReleased","type":"BOOLEAN","mode":"NULLABLE"},{"name":"columnReleased","type":"BOOLEAN","mode":"NULLABLE"},{"name":"pastPeriod","type":"BOOLEAN","mode":"NULLABLE"},{"name":"hasPeriod","type":"BOOLEAN","mode":"NULLABLE"},{"name":"processed","type":"BOOLEAN","mode":"NULLABLE"},{"name":"errorOccured","type":"BOOLEAN","mode":"NULLABLE"},{"name":"errorOccurred","type":"INTEGER","mode":"NULLABLE"},{"name":"historicParticipantGoal","type":"RECORD","mode":"REPEATED","fields":[{"name":"createDate","type":"RECORD","mode":"NULLABLE","fields":[{"name":"date","type":"DATE","mode":"NULLABLE"}]},{"name":"previousResult","type":"RECORD","mode":"NULLABLE","fields":[{"name":"numberDecimal","type":"INTEGER","mode":"NULLABLE"}]},{"name":"updatedResult","type":"RECORD","mode":"NULLABLE","fields":[{"name":"numberDecimal","type":"INTEGER","mode":"NULLABLE"}]},{"name":"simulation","type":"BOOLEAN","mode":"NULLABLE"},{"name":"lastCalculationDate","type":"RECORD","mode":"NULLABLE","fields":[{"name":"date","type":"DATE","mode":"NULLABLE"}]},{"name":"errors","type":"RECORD","mode":"REPEATED","fields":[{"name":"createDate","type":"RECORD","mode":"NULLABLE","fields":[{"name":"date","type":"DATE","mode":"NULLABLE"}]},{"name":"errorMessage","type":"STRING","mode":"NULLABLE"},{"name":"errorDetails","type":"STRING","mode":"NULLABLE"}]}]},{"name":"goalTargetValue","type":"FLOAT","mode":"NULLABLE"},{"name":"simulationResult","type":"FLOAT","mode":"NULLABLE"},{"name":"errorDetails","type":"FLOAT","mode":"NULLABLE"},{"name":"errorMessage","type":"FLOAT","mode":"NULLABLE"},{"name":"id_binary_base64","type":"STRING","mode":"NULLABLE"},{"name":"id_binary_subType","type":"INTEGER","mode":"NULLABLE"},{"name":"campaignId_binary_base64","type":"STRING","mode":"NULLABLE"},{"name":"campaignId_binary_subType","type":"INTEGER","mode":"NULLABLE"},{"name":"batchId_binary_base64","type":"STRING","mode":"NULLABLE"},{"name":"batchId_binary_subType","type":"INTEGER","mode":"NULLABLE"},{"name":"campaignGoalId_binary_base64","type":"STRING","mode":"NULLABLE"},{"name":"campaignGoalId_binary_subType","type":"INTEGER","mode":"NULLABLE"},{"name":"result_numberDecimal","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_dataAceite","type":"STRING","mode":"NULLABLE"},{"name":"metadata_dataReferencia","type":"INTEGER","mode":"NULLABLE"},{"name":"metadata_grupo","type":"TIMESTAMP","mode":"NULLABLE"},{"name":"metadata_nome","type":"STRING","mode":"NULLABLE"},{"name":"metadata_ativo_ph","type":"INTEGER","mode":"NULLABLE"},{"name":"metadata_login","type":"INTEGER","mode":"NULLABLE"},{"name":"createDate_date","type":"DATE","mode":"NULLABLE"},{"name":"participantGoalStatusId_binary_base64","type":"STRING","mode":"NULLABLE"},{"name":"participantGoalStatusId_binary_subType","type":"INTEGER","mode":"NULLABLE"},{"name":"participantId_binary_base64","type":"STRING","mode":"NULLABLE"},{"name":"participantId_binary_subType","type":"INTEGER","mode":"NULLABLE"},{"name":"userId_binary_base64","type":"STRING","mode":"NULLABLE"},{"name":"userId_binary_subType","type":"INTEGER","mode":"NULLABLE"},{"name":"goalTargetValue_numberDecimal","type":"FLOAT","mode":"NULLABLE"},{"name":"simulationResult_numberDecimal","type":"FLOAT","mode":"NULLABLE"},{"name":"participantGoalStatusId","type":"FLOAT","mode":"NULLABLE"},{"name":"participantId","type":"FLOAT","mode":"NULLABLE"},{"name":"userId","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_Premiacao","type":"INTEGER","mode":"NULLABLE"},{"name":"metadata_Corretor","type":"STRING","mode":"NULLABLE"},{"name":"metadata_regional","type":"FLOAT","mode":"NULLABLE"},{"name":"goalRewardValue","type":"FLOAT","mode":"NULLABLE"},{"name":"goalRewardValue_numberDecimal","type":"FLOAT","mode":"NULLABLE"},{"name":"result","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_DOCUMENTO,META,RESULTADO,FAMILIA","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_DOCUMENTO,META,RESULTADO,PRODUTO","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_documento,resultado","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_data","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_referencia","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_Status_Ponto","type":"STRING","mode":"NULLABLE"},{"name":"metadata_DataAceite","type":"STRING","mode":"NULLABLE"},{"name":"metadata_ValidaAAo-Aceite","type":"STRING","mode":"NULLABLE"},{"name":"metadata_ValidaAAo-CheckPH","type":"STRING","mode":"NULLABLE"},{"name":"metadata_Data_Periodo","type":"DATE","mode":"NULLABLE"},{"name":"metadata_Data_Periodo_Ajustada","type":"STRING","mode":"NULLABLE"},{"name":"metadata_Periodo","type":"STRING","mode":"NULLABLE"},{"name":"metadata_Total_Pontos_Bloqueados","type":"INTEGER","mode":"NULLABLE"},{"name":"metadata_Data_Atualizacao","type":"DATE","mode":"NULLABLE"},{"name":"metadata_Grupo","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_periodo","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_posicao","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_DOCUMENTO,RESULTADO,PRODUTO,META","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_Corretor,documento,resultado,Premiacao","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_Corretor;documento;resultado;Premiacao","type":"STRING","mode":"NULLABLE"},{"name":"metadata_documento,dataReferencia,resultado,produto,grupo,nome,login,dataAceite,,,,","type":"STRING","mode":"NULLABLE"},{"name":"metadata_realizado","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_email","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_E-MAIL","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_cod","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_descricao","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_documento,grupo,meta,resultado","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_documento,dataReferencia,resultado,produto,grupo,nome,login,dataAceite","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_documento,resultado,produto,meta","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_corretor","type":"STRING","mode":"NULLABLE"},{"name":"metadata_resultado","type":"FLOAT","mode":"NULLABLE"},{"name":"metadata_Corretor;documento;resultado","type":"FLOAT","mode":"NULLABLE"}]

# %%
count = {i['name'].lower():0 for i in schema}
for i in schema:
    count[i['name'].lower()] += 1
    if count[i['name'].lower()] == 2:
        print(i['name'])

print('\n')

for i in schema:
    for c in i['name']:
        if not c.isalpha() and c != '_' and not c.isnumeric():
            print(i['name'])
            i['name'] = i['name'].replace(',', '_').replace(':', '_').replace(';', '_').replace('-', '_')
            break
# Out:
# metadata_DataAceite
# metadata_Grupo
# metadata_periodo
# metadata_documento,resultado,produto,meta
# metadata_corretor
#
#
# metadata_DOCUMENTO,META,RESULTADO,FAMILIA
# metadata_DOCUMENTO,META,RESULTADO,PRODUTO
# metadata_documento,resultado
# metadata_ValidaAAo-Aceite
# metadata_ValidaAAo-CheckPH
# metadata_DOCUMENTO,RESULTADO,PRODUTO,META
# metadata_Corretor,documento,resultado,Premiacao
# metadata_Corretor;documento;resultado;Premiacao
# metadata_documento,dataReferencia,resultado,produto,grupo,nome,login,dataAceite,,,,
# metadata_E-MAIL
# metadata_documento,grupo,meta,resultado
# metadata_documento,dataReferencia,resultado,produto,grupo,nome,login,dataAceite
# metadata_documento,resultado,produto,meta
# metadata_Corretor;documento;resultado

# %%
metadata_DOCUMENTO,META,RESULTADO,FAMILIA
metadata_DOCUMENTO,META,RESULTADO,PRODUTO
metadata_documento,resultado
metadata_ValidaAAo-Aceite
metadata_ValidaAAo-CheckPH
metadata_DOCUMENTO,RESULTADO,PRODUTO,META
metadata_Corretor,documento,resultado,Premiacao
metadata_Corretor;documento;resultado;Premiacao
metadata_documento,dataReferencia,resultado,produto,grupo,nome,login,dataAceite,,,,
metadata_E-MAIL
metadata_documento,grupo,meta,resultado
metadata_documento,dataReferencia,resultado,produto,grupo,nome,login,dataAceite
metadata_documento,resultado,produto,meta
metadata_Corretor;documento;resultado

# %%
schema
# Out:
# [{'name': 'batchNumber', 'type': 'INTEGER', 'mode': 'NULLABLE'},
#  {'name': 'document', 'type': 'INTEGER', 'mode': 'NULLABLE'},
#  {'name': 'productCode', 'type': 'STRING', 'mode': 'NULLABLE'},
#  {'name': 'creditReleased', 'type': 'BOOLEAN', 'mode': 'NULLABLE'},
#  {'name': 'columnReleased', 'type': 'BOOLEAN', 'mode': 'NULLABLE'},
#  {'name': 'pastPeriod', 'type': 'BOOLEAN', 'mode': 'NULLABLE'},
#  {'name': 'hasPeriod', 'type': 'BOOLEAN', 'mode': 'NULLABLE'},
#  {'name': 'processed', 'type': 'BOOLEAN', 'mode': 'NULLABLE'},
#  {'name': 'errorOccured', 'type': 'BOOLEAN', 'mode': 'NULLABLE'},
#  {'name': 'errorOccurred', 'type': 'INTEGER', 'mode': 'NULLABLE'},
#  {'name': 'historicParticipantGoal',
#   'type': 'RECORD',
#   'mode': 'REPEATED',
#   'fields': [{'name': 'createDate',
#     'type': 'RECORD',
#     'mode': 'NULLABLE',
#     'fields': [{'name': 'date', 'type': 'DATE', 'mode': 'NULLABLE'}]},
#    {'name': 'previousResult',
#     'type': 'RECORD',
#     'mode': 'NULLABLE',
# ...
