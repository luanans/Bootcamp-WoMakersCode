# %%
#Instalação dos pacotes
# !pip install networkx
# !pip install scipy
# !pip install pandas
#!pip install requests

# %%
#Importando pacotes
import networkx as nx
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sp_transporte.csv')

# %%
df.insert(7, "_ordemLinhas", [0]*203, True)
df.insert(8, "_baldeacao", [0]*203, True)
df.insert(9, "_color", [0]*203, True)

# %%
#Ordem linha 1-Azul
df.at[20, '_ordemLinhas'] = 1
#df.at[20, '_baldeacao'] = 1
df.at[8, '_ordemLinhas'] = 2
df.at[6, '_ordemLinhas'] = 3
df.at[13, '_ordemLinhas'] = 4
df.at[2, '_ordemLinhas'] = 5
df.at[10, '_ordemLinhas'] = 6
df.at[1, '_ordemLinhas'] = 7
#df.at[1, '_baldeacao'] = 1
df.at[19, '_ordemLinhas'] = 8
df.at[7, '_ordemLinhas'] = 9
df.at[7, '_baldeacao'] = 1
df.at[14, '_ordemLinhas'] = 10
df.at[18, '_ordemLinhas'] = 11
df.at[18, '_baldeacao'] = 1
df.at[5, '_ordemLinhas'] = 12
df.at[15, '_ordemLinhas'] = 13
df.at[21, '_ordemLinhas'] = 14
df.at[9, '_ordemLinhas'] = 15
df.at[9, '_baldeacao'] = 1
df.at[0, '_ordemLinhas'] = 16
df.at[0, '_baldeacao'] = 1
df.at[22, '_ordemLinhas'] = 17
df.at[12, '_ordemLinhas'] = 18
df.at[12, '_baldeacao'] = 1
df.at[12, '_nome'] = "Santa Cruz"
df.at[11, '_ordemLinhas'] = 19
df.at[17, '_ordemLinhas'] = 20
df.at[16, '_ordemLinhas'] = 21
df.at[3, '_ordemLinhas'] = 22
df.at[4, '_ordemLinhas'] = 23
df.at[4, '_baldeacao'] = 1
df.loc[df["_ordem"] == 1, '_color'] = "#00539f"

# %%
#Ordem linha 2-Verde
df.at[35, "_ordemLinhas"] = 1
df.at[30, "_ordemLinhas"] = 2
df.at[27, "_ordemLinhas"] = 3
df.at[28, "_ordemLinhas"] = 4
df.at[28, '_baldeacao'] = 1
df.at[28, '_nome'] = "Consolação-Paulista"
df.at[34, "_ordemLinhas"] = 5
df.at[25, "_ordemLinhas"] = 6
df.at[29, "_ordemLinhas"] = 7
df.at[29, '_baldeacao'] = 1
df.at[24, "_ordemLinhas"] = 8
df.at[24, '_baldeacao'] = 1
df.at[26, "_ordemLinhas"] = 9
df.at[26, '_baldeacao'] = 1
df.at[26, '_nome'] = "Chácara Klabin"
df.at[32, "_ordemLinhas"] = 10
df.at[23, "_ordemLinhas"] = 11
df.at[31, "_ordemLinhas"] = 12
df.at[33, "_ordemLinhas"] = 13
df.at[33, '_baldeacao'] = 1
df.at[36, "_ordemLinhas"] = 14
df.at[36, '_baldeacao'] = 1
df.loc[df["_ordem"] == 2, '_color'] = "#008062"

# %%
#Ordem linha 3-Vermelha
df.at[46, "_ordemLinhas"] = 1
df.at[46, '_baldeacao'] = 1
df.at[45, "_ordemLinhas"] = 2
df.at[51, "_ordemLinhas"] = 3
df.at[50, "_ordemLinhas"] = 4
df.at[50, '_baldeacao'] = 1
df.at[37, "_ordemLinhas"] = 5
df.at[52, "_ordemLinhas"] = 6
df.at[52, '_baldeacao'] = 1
df.at[48, "_ordemLinhas"] = 7
df.at[40, "_ordemLinhas"] = 8
df.at[40, '_baldeacao'] = 1
df.at[41, "_ordemLinhas"] = 9
df.at[39, "_ordemLinhas"] = 10
df.at[53, "_ordemLinhas"] = 11
df.at[53, '_baldeacao'] = 1
df.at[42, "_ordemLinhas"] = 12
df.at[49, "_ordemLinhas"] = 13
df.at[54, "_ordemLinhas"] = 14
df.at[44, "_ordemLinhas"] = 15
df.at[47, "_ordemLinhas"] = 16
df.at[38, "_ordemLinhas"] = 17
df.at[43, "_ordemLinhas"] = 18
df.at[43, '_baldeacao'] = 1
df.loc[df["_ordem"] == 3, '_color'] = "#ef4035"

# %%
#Ordem linha 4-Amarela
df.at[64, "_ordemLinhas"] = 1
df.at[55, "_ordemLinhas"] = 2
df.at[62, "_ordemLinhas"] = 3
df.at[62, '_baldeacao'] = 1
df.at[56, "_ordemLinhas"] = 4
df.at[57, "_ordemLinhas"] = 5
df.at[60, "_ordemLinhas"] = 6
df.at[61, "_ordemLinhas"] = 7
df.at[61, '_baldeacao'] = 1
df.at[61, '_nome'] = "Consolação-Paulista"
df.at[58, "_ordemLinhas"] = 8
df.at[63, "_ordemLinhas"] = 9
df.at[63, '_baldeacao'] = 1
df.at[59, "_ordemLinhas"] = 10
df.at[59, '_baldeacao'] = 1
df.loc[df["_ordem"] == 4, '_color'] = "#ffd503"

# %%
#Ordem linha 5-Lilás
df.at[72, "_ordemLinhas"] = 1
df.at[71, "_ordemLinhas"] = 2
df.at[81, "_ordemLinhas"] = 3
df.at[75, "_ordemLinhas"] = 4
df.at[80, "_ordemLinhas"] = 5
df.at[80, '_baldeacao'] = 1
df.at[77, "_ordemLinhas"] = 6
df.at[66, "_ordemLinhas"] = 7
df.at[67, "_ordemLinhas"] = 8
df.at[68, "_ordemLinhas"] = 9
df.at[69, "_ordemLinhas"] = 10
df.at[70, "_ordemLinhas"] = 11
df.at[74, "_ordemLinhas"] = 12
df.at[78, "_ordemLinhas"] = 13
df.at[65, "_ordemLinhas"] = 14
df.at[76, "_ordemLinhas"] = 15
df.at[79, "_ordemLinhas"] = 16
df.at[79, '_baldeacao'] = 1
df.at[73, "_ordemLinhas"] = 17
df.at[73, '_baldeacao'] = 1
df.loc[df["_ordem"] == 5, '_color'] = "#794d9f"

# %%
#Ordem linha 7-Rubi (Luz-Francisco Morato-Jundiaí)
df.at[90, "_ordemLinhas"] = 1
df.at[97, "_ordemLinhas"] = 2
df.at[86, "_ordemLinhas"] = 3
df.at[84, "_ordemLinhas"] = 4
df.at[87, "_ordemLinhas"] = 5
df.at[83, "_ordemLinhas"] = 6
df.at[88, "_ordemLinhas"] = 7
df.at[85, "_ordemLinhas"] = 8
df.at[94, "_ordemLinhas"] = 9
df.at[98, "_ordemLinhas"] = 10
df.at[89, "_ordemLinhas"] = 11
df.at[99, "_ordemLinhas"] = 12
df.at[96, "_ordemLinhas"] = 13
df.at[95, "_ordemLinhas"] = 14
df.at[91, "_ordemLinhas"] = 15
df.at[91, "_nome"] = "Lapa_7"
df.at[82, "_ordemLinhas"] = 16
df.at[93, "_ordemLinhas"] = 17
df.at[93, '_baldeacao'] = 1
df.at[92, "_ordemLinhas"] = 18
df.at[92, '_baldeacao'] = 1
#Faltou Bras:
id_adicional = 300
new_row = pd.Series({
    '_estacaoId': id_adicional,
    "_nome": "Brás",
    "_ordem": 7,
    "_linhaId": 4,
    "_linha": "7-Rubi (Luz-Francisco Morato-Jundiaí)",
    "_tipoId": 2,
    "_tipo": "CPTM",
    "_ordemLinhas": 19,
    "_baldeacao": 1
})
df = pd.concat([df, new_row.to_frame().T], ignore_index=True)
df.loc[df["_ordem"] == 7, '_color'] = "#9f1866"

# %%
#Ordem linha 8-Diamante (Júlio Prestes-Itapevi-Amador Bueno)
new_rows = {
    "_estacaoId": [id_adicional+1, id_adicional+2],
    "_nome": ["Amador Bueno", "Santa Rita"],
    "_ordem": [8, 8],
    "_linhaId": [5, 5],
    "_linha": ["8-Diamante (Júlio Prestes-Itapevi-Amador Bueno)", "8-Diamante (Júlio Prestes-Itapevi-Amador Bueno)"],
    "_tipoId": [2, 2],
    "_tipo": ["CPTM", "CPTM"],
    "_ordemLinhas": [1, 2],
    "_baldeacao": [0, 0]
}
new_df = pd.DataFrame.from_dict(new_rows)
df.at[108, "_ordemLinhas"] = 3
df.at[105, "_ordemLinhas"] = 4
df.at[118, "_ordemLinhas"] = 5
df.at[109, "_ordemLinhas"] = 6
df.at[111, "_ordemLinhas"] = 7
df.at[110, "_ordemLinhas"] = 8
df.at[101, "_ordemLinhas"] = 9
df.at[100, "_ordemLinhas"] = 10
df.at[119, "_ordemLinhas"] = 11
df.at[102, "_ordemLinhas"] = 12
df.at[106, "_ordemLinhas"] = 13
df.at[117, "_ordemLinhas"] = 14
df.at[103, "_ordemLinhas"] = 15
df.at[114, "_ordemLinhas"] = 18
df.at[114, '_baldeacao'] = 1
df.at[116, "_ordemLinhas"] = 17
df.at[116, '_baldeacao'] = 1
df.at[107, "_ordemLinhas"] = 18
df.at[104, "_ordemLinhas"] = 19
df.at[113, "_ordemLinhas"] = 20
df.at[113, "_nome"] = "Lapa_8"
df.at[115, "_ordemLinhas"] = 21
df.at[115, '_baldeacao'] = 1
df.at[112, "_ordemLinhas"] = 22
df = pd.concat([df, new_df], ignore_index=True)
df.loc[df["_ordem"] == 8, '_color'] = "#9e9e94"

# %%
#Ordem linha 9-Esmeralda (Osasco-Grajaú)
df.at[130, "_ordemLinhas"] = 1
df.at[130, '_baldeacao'] = 1
df.at[132, "_ordemLinhas"] = 2
df.at[132, '_baldeacao'] = 1
df.at[122, "_ordemLinhas"] = 3
df.at[136, "_ordemLinhas"] = 4
df.at[124, "_ordemLinhas"] = 5
df.at[131, "_ordemLinhas"] = 6
df.at[131, '_baldeacao'] = 1
df.at[127, "_ordemLinhas"] = 7
df.at[123, "_ordemLinhas"] = 8
df.at[137, "_ordemLinhas"] = 9
df.at[121, "_ordemLinhas"] = 10
df.at[121, '_baldeacao'] = 1
df.at[129, "_ordemLinhas"] = 11
df.at[129, '_baldeacao'] = 1
df.at[126, "_ordemLinhas"] = 12
df.at[134, "_ordemLinhas"] = 13
df.at[134, '_baldeacao'] = 1
df.at[135, "_ordemLinhas"] = 14
df.at[128, "_ordemLinhas"] = 15
df.at[120, "_ordemLinhas"] = 16
df.at[133, "_ordemLinhas"] = 17
df.at[125, "_ordemLinhas"] = 18
df.loc[df["_ordem"] == 9, '_color'] = "#00a88e"

# %%
#Ordem linha 10-Turquesa (Luz-Rio Grande da Serra)
df.at[138, "_ordemLinhas"] = 1
df.at[138, '_baldeacao'] = 1
df.at[143, "_ordemLinhas"] = 2
df.at[141, "_ordemLinhas"] = 3
df.at[149, "_ordemLinhas"] = 4
df.at[149, '_baldeacao'] = 1
df.at[148, "_ordemLinhas"] = 5
df.at[150, "_ordemLinhas"] = 6
df.at[144, "_ordemLinhas"] = 7
df.at[147, "_ordemLinhas"] = 8
df.at[147, '_baldeacao'] = 1
df.at[139, "_ordemLinhas"] = 9
df.at[142, "_ordemLinhas"] = 10
df.at[140, "_ordemLinhas"] = 11
df.at[145, "_ordemLinhas"] = 12
df.at[146, "_ordemLinhas"] = 13
df.loc[df["_ordem"] == 10, '_color'] = "#007d8e"

# %%
#Ordem linha 11 (as duas juntas)
df.at[166, "_ordemLinhas"] = 1
df.at[166, '_baldeacao'] = 1
df.at[161, "_ordemLinhas"] = 2
df.at[161, '_baldeacao'] = 1
df.at[167, "_ordemLinhas"] = 3
df.at[167, '_baldeacao'] = 1
df.at[162, "_ordemLinhas"] = 4
df.at[162, '_baldeacao'] = 1
df.at[163, "_ordemLinhas"] = 5
df.at[165, "_ordemLinhas"] = 6
df.at[164, "_ordemLinhas"] = 7
df.at[156, "_ordemLinhas"] = -1 #Está repetida
df.at[151, "_ordemLinhas"] = 8
df.at[155, "_ordemLinhas"] = 9
df.at[159, "_ordemLinhas"] = 10
df.at[153, "_ordemLinhas"] = 11
df.at[153, '_baldeacao'] = 1
df.at[160, "_ordemLinhas"] = 12
df.at[157, "_ordemLinhas"] = 13
df.at[152, "_ordemLinhas"] = 14
df.at[158, "_ordemLinhas"] = 15
df.at[154, "_ordemLinhas"] = 16
df.loc[df["_ordem"] == 11, '_color'] = "#f04e23"

# %%
#Ordem linha 12-Safira (Brás-Calmon Viana)
df.at[169, "_ordemLinhas"] = 1
df.at[169, '_baldeacao'] = 1
df.at[179, "_ordemLinhas"] = 2
df.at[179, '_baldeacao'] = 1
df.at[172, "_ordemLinhas"] = 3
df.at[172, '_baldeacao'] = 1
df.at[180, "_ordemLinhas"] = 4
df.at[171, "_ordemLinhas"] = 5
df.at[178, "_ordemLinhas"] = 6
df.at[176, "_ordemLinhas"] = 7
df.at[174, "_ordemLinhas"] = 8
df.at[177, "_ordemLinhas"] = 9
df.at[173, "_ordemLinhas"] = 10
df.at[175, "_ordemLinhas"] = 11
df.at[168, "_ordemLinhas"] = 12
df.at[170, "_ordemLinhas"] = 13
df.at[170, '_baldeacao'] = 1
df.loc[df["_ordem"] == 12, '_color'] = "#083f87"

# %%
#Ordem linha 13-Jade
df.at[181, "_ordemLinhas"] = 1
df.at[183, "_ordemLinhas"] = 2
df.at[182, "_ordemLinhas"] = 3
df.at[182, '_baldeacao'] = 1
df.at[182, '_nome'] = "Engenheiro Goulart"
df.at[189, "_ordemLinhas"] = -1
df.at[190, "_ordemLinhas"] = -1
df.at[185, "_ordemLinhas"] = -1
df.at[188, "_ordemLinhas"] = -1
df.at[186, "_ordemLinhas"] = -1
df.at[187, "_ordemLinhas"] = -1
df.at[184, "_ordemLinhas"] = -1
df.loc[df["_ordem"] == 13, '_color'] = "#00ad5c"

# %%
#Ordem linha 15-Prata
df.at[191, "_ordemLinhas"] = 1
df.at[191, '_baldeacao'] = 1
df.at[187, "_ordemLinhas"] = 2
df.at[188, "_ordemLinhas"] = 3
df.at[184, "_ordemLinhas"] = 4
df.at[192, "_ordemLinhas"] = 5
df.at[193, "_ordemLinhas"] = 6
df.at[186, "_ordemLinhas"] = 7
df.at[190, "_ordemLinhas"] = 8
df.at[185, "_ordemLinhas"] = 9
df.at[189, "_ordemLinhas"] = 10
df.at[189, '_baldeacao'] = 1
df.loc[df["_ordem"] == 15, '_color'] = "#858d90"

# %%
#Ordem linha EMTU
new_row = pd.Series({
    '_estacaoId': id_adicional+3,
    "_nome": "Berrini",
    "_ordem": 999,
    "_linhaId": 11,
    "_linha": "EMTU",
    "_tipoId": 3,
    "_tipo": "EMTU",
    "_ordemLinhas": 1,
    "_baldeacao": 1
})
df = pd.concat([df, new_row.to_frame().T], ignore_index=True)
df.at[197, "_ordemLinhas"] = 2
df.at[197, '_baldeacao'] = 1
df.at[194, "_ordemLinhas"] = 3
df.at[198, "_ordemLinhas"] = 4
df.at[200, "_ordemLinhas"] = 5
df.at[199, "_ordemLinhas"] = 6
df.at[199, '_baldeacao'] = 1
df.at[202, "_ordemLinhas"] = 7
df.at[201, "_ordemLinhas"] = 8
df.at[201, '_baldeacao'] = 1
df.at[195, "_ordemLinhas"] = 999
df.at[196, "_ordemLinhas"] = 999
df.at[196, '_baldeacao'] = 1
df.loc[df["_ordem"] == 999, '_color'] = "#0053a0"
