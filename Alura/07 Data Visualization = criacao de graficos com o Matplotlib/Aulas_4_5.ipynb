# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Aula 4 - Visualizando dados diferentes

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala  \
# 0                 5.1             3.5                 1.4             0.2
# 1                 4.9             3.0                 1.4             0.2
# 2                 4.7             3.2                 1.3             0.2
# 3                 4.6             3.1                 1.5             0.2
# 4                 5.0             3.6                 1.4             0.2
#
#        espécie
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df.describe()
# Out:
#        comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala
# count          150.000000      150.000000          150.000000      150.000000
# mean             5.843333        3.054000            3.758667        1.198667
# std              0.828066        0.433594            1.764420        0.763161
# min              4.300000        2.000000            1.000000        0.100000
# 25%              5.100000        2.800000            1.600000        0.300000
# 50%              5.800000        3.000000            4.350000        1.300000
# 75%              6.400000        3.300000            5.100000        1.800000
# max              7.900000        4.400000            6.900000        2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   comprimento_sépala  150 non-null    float64
#  1   largura_sépala      150 non-null    float64
#  2   comprimento_pétala  150 non-null    float64
#  3   largura_pétala      150 non-null    float64
#  4   espécie             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
fig = plt.figure(figsize=(18,6))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimeto da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(18,6))
eixo = fig.add_axes([0,0,1,1])

eixo.scatter(df['comprimento_sépala'], df['largura_sépala'])
eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimeto da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=13)
plt.show()

# %%
df
# Out:
#      comprimento_sépala  largura_sépala  comprimento_pétala  largura_pétala  \
# 0                   5.1             3.5                 1.4             0.2
# 1                   4.9             3.0                 1.4             0.2
# 2                   4.7             3.2                 1.3             0.2
# 3                   4.6             3.1                 1.5             0.2
# 4                   5.0             3.6                 1.4             0.2
# ..                  ...             ...                 ...             ...
# 145                 6.7             3.0                 5.2             2.3
# 146                 6.3             2.5                 5.0             1.9
# 147                 6.5             3.0                 5.2             2.0
# 148                 6.2             3.4                 5.4             2.3
# 149                 5.9             3.0                 5.1             1.8
#
#             espécie
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 5 columns]

# %%
fig = plt.figure(figsize=(18,6))
eixo = fig.add_axes([0,0,1,1])

colors = {key: value for key, value in zip(df.espécie.unique(), ['indigo', 'mediumorchid', 'slateblue'])}

for e in df.espécie.unique():
    eixo.scatter(df[df.espécie == e]['comprimento_sépala'], df[df.espécie == e]['largura_sépala'], color=colors[e])

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimeto da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=13)
eixo.legend(colors, fontsize=15)
plt.show()

# %%
fig = plt.figure(figsize=(18,6))
eixo = fig.add_axes([0,0,1,1])

colors = {key: value for key, value in zip(df.espécie.unique(), ['indigo', 'mediumorchid', 'slateblue'])}
marcadores = {key: value for key, value in zip(df.espécie.unique(), ['x', 'o', 'v'])}
for e in df.espécie.unique():
    eixo.scatter(
        df[df.espécie == e]['comprimento_sépala'],
        df[df.espécie == e]['largura_sépala'],
        color=colors[e],
        marker=marcadores[e]
        )

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimeto da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=13)
eixo.legend(colors, fontsize=15)
plt.show()

# %%
fig = plt.figure(figsize=(18,6))
eixo = fig.add_axes([0,0,1,1])

colors = {key: value for key, value in zip(df.espécie.unique(), ['indigo', 'mediumorchid', 'slateblue'])}
marcadores = {key: value for key, value in zip(df.espécie.unique(), ['x', 'o', 'v'])}
for e in df.espécie.unique():
    eixo.scatter(
        df[df.espécie == e]['comprimento_sépala'],
        df[df.espécie == e]['largura_sépala'],
        color=colors[e],
        marker=marcadores[e],
        s=100
        )

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimeto da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=13)
eixo.legend(colors, fontsize=15)
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

cores = {'Iris-setosa': 'r', 'Iris-versicolor': 'b', 'Iris-virginica': 'g'}
marcadores = {'Iris-setosa': 'x', 'Iris-versicolor': 'o', 'Iris-virginica': 'v'}

for especie in df['espécie'].unique():
    tmp = df[df['espécie'] == especie]
    eixo.scatter(tmp['comprimento_sépala'], tmp['largura_sépala'],
                 color=cores[especie], marker=marcadores[especie],
                 s=100)

eixo.set_title('Gráfico de dispersão', fontsize=25, pad=15)
eixo.set_xlabel('Comprimento da sépala', fontsize=15)
eixo.set_ylabel('Largura da sépala', fontsize=15)
eixo.tick_params(labelsize=15)

eixo.legend(cores, fontsize=20)

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df.drop('espécie', axis=1))
eixo.set_title('Boxplot', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1))
# Out:
# [Text(1, 0, 'comprimento_sépala'),
#  Text(2, 0, 'largura_sépala'),
#  Text(3, 0, 'comprimento_pétala'),
#  Text(4, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

eixo.boxplot(df.drop('espécie', axis=1), patch_artist=True)
eixo.set_title('Boxplot', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1))
# Out:
# [Text(1, 0, 'comprimento_sépala'),
#  Text(2, 0, 'largura_sépala'),
#  Text(3, 0, 'comprimento_pétala'),
#  Text(4, 0, 'largura_pétala')]

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

colors = ['gold', 'tomato','mediumslateblue', 'springgreen']

boxes = eixo.boxplot(df.drop('espécie', axis=1), patch_artist=True)
eixo.set_title('Boxplot', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1))

for box, color in zip(boxes['boxes'], colors):
    box.set(color=color)

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

colors = ['gold', 'tomato','mediumslateblue', 'springgreen']

boxes = eixo.boxplot(df.drop('espécie', axis=1), patch_artist=True)
eixo.set_title('Boxplot', fontsize=15, pad=10)
eixo.set_xticklabels(df.drop('espécie', axis=1))

for box, color in zip(boxes['boxes'], colors):
    box.set(color=color)

for outlier in boxes['fliers']:
    outlier.set(marker='x', markersize=8, markeredgecolor='tomato')

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df.comprimento_pétala)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df.comprimento_pétala, bins=50)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df.comprimento_pétala, bins=50, orientation='horizontal')
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(8,4))
eixo = fig.add_axes([0,0,1,1])

eixo.hist(df.comprimento_pétala, bins=50, density=True)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu , sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df.comprimento_pétala, bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate(
    '$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
    xy=(4.5,20),
    fontsize=30
)

plt.plot()
# Out:
# []

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

mu , sigma = df['comprimento_pétala'].mean(), df['comprimento_pétala'].std()

eixo.hist(df.comprimento_pétala, bins=20)
eixo.set_title('Histograma', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate(
    '$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
    xy=(4.5,20),
    fontsize=30
)

eixo.axvline(mu, color='k', linestyle='--')
eixo.annotate('média', xy=(mu-0.8, 28))

eixo.axvline(df.comprimento_pétala.median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(mu+0.8, 28), color='g')

plt.plot()
# Out:
# []

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_iv = df[df['espécie'] == 'Iris-versicolor']

mu, sigma = df_iv['comprimento_pétala'].mean(), df_iv['comprimento_pétala'].std()

eixo.hist(df_iv['comprimento_pétala'], bins=20)
eixo.set_title('Iris Versicolor', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
               xy=(4.6, 6), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('média', xy=(mu-0.5, 5.5), fontsize=20)

eixo.axvline(df_iv['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_iv['comprimento_pétala'].median()-0.7, 6.5), fontsize=20,
               color='g')

fig.savefig('histograma_iv.png', bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_is = df[df['espécie'] == 'Iris-setosa']

mu, sigma = df_is['comprimento_pétala'].mean(), df_is['comprimento_pétala'].std()

eixo.hist(df_is['comprimento_pétala'], bins=20)
eixo.set_title('Iris Setosa', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
               xy=(1.7, 7), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('média', xy=(mu-0.2, 13.5), fontsize=20)

eixo.axvline(df_is['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_is['comprimento_pétala'].median()+0.05, 12), fontsize=20,
               color='g')

fig.savefig('histograma_is.png', bbox_inches='tight')

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_ivc = df[df['espécie'] == 'Iris-virginica']

mu, sigma = df_ivc['comprimento_pétala'].mean(), df_ivc['comprimento_pétala'].std()

eixo.hist(df_ivc['comprimento_pétala'], bins=20)
eixo.set_title('Iris Virginca', fontsize=15, pad=10)
eixo.set_xlabel('Comprimento da pétala', fontsize=15)
eixo.grid(True)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma = {1:.2f}$'.format(mu, sigma),
               xy=(6.3, 7), fontsize=20)

eixo.axvline(mu, color = 'k', linestyle='--')
eixo.annotate('média', xy=(mu, 8), fontsize=20)

eixo.axvline(df_ivc['comprimento_pétala'].median(), color='g', linestyle='--')
eixo.annotate('mediana', xy=(df_ivc['comprimento_pétala'].median(), 7), fontsize=20,
               color='g')

fig.savefig('histograma_ivg.png', bbox_inches='tight')

# %%
   directory = '/home/lnunes/files'
   pathlist = Path(directory).glob(table_name +'*.json')
   for file_json in pathlist:

# %%
from PIL import Image
from pathlib import Path

largura, altura = Image.open('histograma_is.png').size
combinada = Image.new("RGB", (3*largura, altura))
intervalo = 0


directory = '.'
pathlist = [str(p) for p in Path(directory).glob('his*.png')]

for image in map(Image.open, pathlist):
    combinada.paste(image, (intervalo, 0))
    intervalo += largura

combinada.save("combinada.png")

# %%
combinada
# Out:
# <PIL.Image.Image image mode=RGB size=1641x500>

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

df_is = df[df['espécie'] == 'Iris-setosa']

mu, sigma = df_is['comprimento_pétala'].mean(), df_is['comprimento_pétala'].std()

eixo.hist(df_is['comprimento_pétala'], bins = 10)
eixo.grid(True)
eixo.set_title('Histograma Iris Setosa', fontsize = 15, pad = 10)
eixo.set_xlabel('Comprimento da pétala', fontsize = 15)

eixo.annotate('$\mu = {0:.2f}$\n$\sigma={1:.2f}$'.format(mu, sigma), 
              xy=(1.7, 7), fontsize=20)

eixo.annotate('média', xy=(df_is['comprimento_pétala'].mean()-0.2, 13.5), fontsize=20)
eixo.axvline(df_is['comprimento_pétala'].mean(), color='k', linestyle='--')

eixo.annotate('mediana', xy=(df_is['comprimento_pétala'].median()+0.05, 12), fontsize=20, color = 'g')
eixo.axvline(df_is['comprimento_pétala'].median(), color='g', linestyle='--')

fig.savefig('histograma_is.png', bbox_inches='tight')

# %% [markdown]
# Durante esta semana, meu foco de aprendizado foi a biblioteca matplotlib.pyplot. Durante as aulas, relembrei como converter dados para datetime e aprendi a criar gráficos de linha, adicionando textos e objetos do tipo figura, além de posicionar os eixos e colocar labels para diferenciá-los. Aprendi também a alterar a fonte dos elementos textuais do gráfico, mudar as cores e espessura das linhas, bem como adicionar linhas de restrição, anotações localizadas e setas para destacar informações importantes.
#
# No que diz respeito ao gráfico de pizza, aprendi a criar e personalizar suas características, como adicionar sombras, cores e destacar porções. Já para o gráfico de barras, aprendi a adicionar bordas e cores. Além disso, aprendi a representar diferentes conjuntos de dados usando o gráfico de dispersão, bem como criar boxplots para uma ou várias variáveis, trocar marcadores e modificar a quantidade de colunas do histograma, bem como sua orientação e normalização.
#
# Por fim, aprimorei minhas habilidades em adicionar anotações matemáticas, salvar figuras e combinar várias imagens em um único gr
